# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

class MinecraftCNNTrainer:
    def __init__(self, dataset_path, img_size=224, batch_size=32):
        self.dataset_path = dataset_path
        self.img_size = img_size
        self.batch_size = batch_size
        self.model = None
        self.history = None
        self.class_names = []
        
    def setup_data_generators(self):
        """Configura los generadores de datos con data augmentation"""
        print("🔧 Configurando generadores de datos...")
        
        # Data augmentation para entrenamiento
        train_datagen = ImageDataGenerator(
            rescale=1./255,
            rotation_range=20,
            width_shift_range=0.2,
            height_shift_range=0.2,
            shear_range=0.15,
            zoom_range=0.2,
            horizontal_flip=True,
            fill_mode='nearest',
            validation_split=0.2  # 80% train, 20% validation
        )
        
        # Solo rescaling para validación
        val_datagen = ImageDataGenerator(
            rescale=1./255,
            validation_split=0.2
        )
        
        # Generador de entrenamiento
        self.train_generator = train_datagen.flow_from_directory(
            self.dataset_path,
            target_size=(self.img_size, self.img_size),
            batch_size=self.batch_size,
            class_mode='categorical',
            subset='training',
            shuffle=True
        )
        
        # Generador de validación
        self.val_generator = val_datagen.flow_from_directory(
            self.dataset_path,
            target_size=(self.img_size, self.img_size),
            batch_size=self.batch_size,
            class_mode='categorical',
            subset='validation',
            shuffle=False
        )
        
        self.class_names = list(self.train_generator.class_indices.keys())
        self.num_classes = len(self.class_names)
        
        print(f"✅ Clases encontradas: {self.class_names}")
        print(f"📊 Imágenes de entrenamiento: {self.train_generator.samples}")
        print(f"📊 Imágenes de validación: {self.val_generator.samples}")
        
    def create_model(self, use_transfer_learning=True):
        """Crea el modelo CNN"""
        print("🧠 Creando modelo CNN...")
        
        if use_transfer_learning:
            # Modelo con Transfer Learning (MobileNetV2)
            base_model = MobileNetV2(
                weights='imagenet',
                include_top=False,
                input_shape=(self.img_size, self.img_size, 3)
            )
            base_model.trainable = False  # Congela las capas base inicialmente
            
            self.model = keras.Sequential([
                base_model,
                layers.GlobalAveragePooling2D(),
                layers.Dropout(0.3),
                layers.Dense(128, activation='relu'),
                layers.Dropout(0.2),
                layers.Dense(self.num_classes, activation='softmax')
            ])
            
            print("✅ Modelo con Transfer Learning creado (MobileNetV2)")
            
        else:
            # Modelo CNN desde cero
            self.model = keras.Sequential([
                layers.Conv2D(32, 3, activation='relu', input_shape=(self.img_size, self.img_size, 3)),
                layers.MaxPooling2D(),
                layers.Conv2D(64, 3, activation='relu'),
                layers.MaxPooling2D(),
                layers.Conv2D(128, 3, activation='relu'),
                layers.MaxPooling2D(),
                layers.Conv2D(128, 3, activation='relu'),
                layers.MaxPooling2D(),
                
                layers.Flatten(),
                layers.Dropout(0.5),
                layers.Dense(512, activation='relu'),
                layers.Dropout(0.3),
                layers.Dense(self.num_classes, activation='softmax')
            ])
            
            print("✅ Modelo CNN desde cero creado")
        
        # Compila el modelo
        self.model.compile(
            optimizer=Adam(learning_rate=0.001),
            loss='categorical_crossentropy',
            metrics=['accuracy']
        )
        
        print(f"📋 Resumen del modelo:")
        self.model.summary()
        
    def setup_callbacks(self):
        """Configura callbacks para el entrenamiento"""
        callbacks = [
            EarlyStopping(
                monitor='val_loss',
                patience=10,
                restore_best_weights=True,
                verbose=1
            ),
            ModelCheckpoint(
                'best_minecraft_model.h5',
                monitor='val_accuracy',
                save_best_only=True,
                verbose=1
            ),
            ReduceLROnPlateau(
                monitor='val_loss',
                factor=0.5,
                patience=5,
                min_lr=1e-7,
                verbose=1
            )
        ]
        return callbacks
        
    def train_model(self, epochs=50):
        """Entrena el modelo"""
        print(f"🚀 Iniciando entrenamiento por {epochs} épocas...")
        
        callbacks = self.setup_callbacks()
        
        self.history = self.model.fit(
            self.train_generator,
            validation_data=self.val_generator,
            epochs=epochs,
            callbacks=callbacks,
            verbose=1
        )
        
        print("✅ Entrenamiento completado!")
        
    def plot_training_history(self):
        """Visualiza el progreso del entrenamiento"""
        if self.history is None:
            print("❌ No hay historial de entrenamiento para mostrar")
            return
            
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
        
        # Accuracy
        ax1.plot(self.history.history['accuracy'], label='Training Accuracy')
        ax1.plot(self.history.history['val_accuracy'], label='Validation Accuracy')
        ax1.set_title('Model Accuracy')
        ax1.set_xlabel('Epoch')
        ax1.set_ylabel('Accuracy')
        ax1.legend()
        ax1.grid(True)
        
        # Loss
        ax2.plot(self.history.history['loss'], label='Training Loss')
        ax2.plot(self.history.history['val_loss'], label='Validation Loss')
        ax2.set_title('Model Loss')
        ax2.set_xlabel('Epoch')
        ax2.set_ylabel('Loss')
        ax2.legend()
        ax2.grid(True)
        
        plt.tight_layout()
        plt.show()
        
    def evaluate_model(self):
        """Evalúa el modelo en el conjunto de validación"""
        print("📊 Evaluando modelo...")
        
        # Predicciones en validación
        predictions = self.model.predict(self.val_generator)
        y_pred = np.argmax(predictions, axis=1)
        y_true = self.val_generator.classes
        
        # Classification report
        print("\n📋 Reporte de Clasificación:")
        print(classification_report(y_true, y_pred, target_names=self.class_names))
        
        # Matriz de confusión
        cm = confusion_matrix(y_true, y_pred)
        plt.figure(figsize=(8, 6))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                   xticklabels=self.class_names, yticklabels=self.class_names)
        plt.title('Matriz de Confusión - Mobs de Minecraft')
        plt.xlabel('Predicción')
        plt.ylabel('Verdadero')
        plt.show()
        
    def save_model(self, filename='minecraft_mob_classifier.h5'):
        """Guarda el modelo entrenado"""
        self.model.save(filename)
        print(f"💾 Modelo guardado como: {filename}")
        
    def load_model(self, filename):
        """Carga un modelo previamente entrenado"""
        self.model = keras.models.load_model(filename)
        print(f"📂 Modelo cargado desde: {filename}")
        
    def predict_single_image(self, image_path):
        """Predice la clase de una sola imagen"""
        if self.model is None:
            print("❌ Primero debes entrenar o cargar un modelo")
            return
            
        # Carga y preprocesa la imagen
        img = keras.preprocessing.image.load_img(image_path, target_size=(self.img_size, self.img_size))
        img_array = keras.preprocessing.image.img_to_array(img)
        img_array = np.expand_dims(img_array, axis=0) / 255.0
        
        # Hace la predicción
        predictions = self.model.predict(img_array)
        predicted_class = np.argmax(predictions[0])
        confidence = predictions[0][predicted_class]
        
        print(f"🎯 Predicción: {self.class_names[predicted_class]}")
        print(f"🎲 Confianza: {confidence:.2%}")
        
        return self.class_names[predicted_class], confidence


def main():
    # Configuración
    DATASET_PATH = "C:/Users/Janus/OneDrive - IUE/SEMESTRE 2025-2/IA II/Dataset/Imagenes redimensionadas"  # Cambia por tu ruta
    IMG_SIZE = 224
    BATCH_SIZE = 32
    EPOCHS = 30
    
    print("🎮 Entrenador de CNN para Mobs de Minecraft")
    print("=" * 50)
    
    # Inicializa el entrenador
    trainer = MinecraftCNNTrainer(DATASET_PATH, IMG_SIZE, BATCH_SIZE)
    
    # Configura datos
    trainer.setup_data_generators()
    
    # Crea modelo (usa Transfer Learning por defecto)
    trainer.create_model(use_transfer_learning=True)
    
    # Entrena el modelo
    trainer.train_model(epochs=EPOCHS)
    
    # Visualiza resultados
    trainer.plot_training_history()
    trainer.evaluate_model()
    
    # Guarda el modelo
    trainer.save_model("minecraft_mob_classifier_final.h5")
    
    print("\n🎉 ¡Entrenamiento completado!")
    print("💡 Para usar el modelo:")
    print("   trainer.predict_single_image('path_to_image.jpg')")


if __name__ == "__main__":
    main()
# Out:
# 🎮 Entrenador de CNN para Mobs de Minecraft
# ==================================================
# 🔧 Configurando generadores de datos...
# Found 1228 images belonging to 3 classes.
# Found 305 images belonging to 3 classes.
# ✅ Clases encontradas: ['aldeanos', 'creepers', 'vacas']
# 📊 Imágenes de entrenamiento: 1228
# 📊 Imágenes de validación: 305
# 🧠 Creando modelo CNN...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# ✅ Modelo con Transfer Learning creado (MobileNetV2)
# 📋 Resumen del modelo:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,422,339 (9.24 MB)
#  Trainable params: 164,355 (642.01 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)
# 🚀 Iniciando entrenamiento por 30 épocas...
# c:\Users\Janus\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 888ms/step - accuracy: 0.5674 - loss: 0.9859
# Epoch 1: val_accuracy improved from -inf to 0.84590, saving model to best_minecraft_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 51s 1s/step - accuracy: 0.5702 - loss: 0.9804 - val_accuracy: 0.8459 - val_loss: 0.4090 - learning_rate: 0.0010
# Epoch 2/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 875ms/step - accuracy: 0.8262 - loss: 0.4392
# Epoch 2: val_accuracy did not improve from 0.84590
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.8261 - loss: 0.4392 - val_accuracy: 0.8295 - val_loss: 0.3656 - learning_rate: 0.0010
# Epoch 3/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 801ms/step - accuracy: 0.8777 - loss: 0.3432
# Epoch 3: val_accuracy did not improve from 0.84590
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 38s 973ms/step - accuracy: 0.8773 - loss: 0.3436 - val_accuracy: 0.8459 - val_loss: 0.3843 - learning_rate: 0.0010
# Epoch 4/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 832ms/step - accuracy: 0.8683 - loss: 0.3584
# Epoch 4: val_accuracy improved from 0.84590 to 0.88852, saving model to best_minecraft_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 39s 988ms/step - accuracy: 0.8682 - loss: 0.3583 - val_accuracy: 0.8885 - val_loss: 0.3201 - learning_rate: 0.0010
# Epoch 5/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 803ms/step - accuracy: 0.8723 - loss: 0.2997
# Epoch 5: val_accuracy did not improve from 0.88852
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 37s 949ms/step - accuracy: 0.8725 - loss: 0.2995 - val_accuracy: 0.8459 - val_loss: 0.3512 - learning_rate: 0.0010
# Epoch 6/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 782ms/step - accuracy: 0.8913 - loss: 0.2651
# Epoch 6: val_accuracy did not improve from 0.88852
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 36s 930ms/step - accuracy: 0.8914 - loss: 0.2649 - val_accuracy: 0.8852 - val_loss: 0.2887 - learning_rate: 0.0010
# Epoch 7/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 843ms/step - accuracy: 0.8847 - loss: 0.2859
# Epoch 7: val_accuracy did not improve from 0.88852
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 39s 998ms/step - accuracy: 0.8849 - loss: 0.2860 - val_accuracy: 0.8787 - val_loss: 0.3014 - learning_rate: 0.0010
# Epoch 8/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 807ms/step - accuracy: 0.9050 - loss: 0.2511
# Epoch 8: val_accuracy did not improve from 0.88852
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 37s 953ms/step - accuracy: 0.9048 - loss: 0.2512 - val_accuracy: 0.8689 - val_loss: 0.2933 - learning_rate: 0.0010
# Epoch 9/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 807ms/step - accuracy: 0.8861 - loss: 0.2559
# Epoch 9: val_accuracy improved from 0.88852 to 0.89508, saving model to best_minecraft_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 38s 978ms/step - accuracy: 0.8864 - loss: 0.2558 - val_accuracy: 0.8951 - val_loss: 0.2691 - learning_rate: 0.0010
# Epoch 10/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 822ms/step - accuracy: 0.9055 - loss: 0.2527
# Epoch 10: val_accuracy did not improve from 0.89508
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 39s 985ms/step - accuracy: 0.9056 - loss: 0.2524 - val_accuracy: 0.8754 - val_loss: 0.2817 - learning_rate: 0.0010
# Epoch 11/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 834ms/step - accuracy: 0.9135 - loss: 0.2193
# Epoch 11: val_accuracy did not improve from 0.89508
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 38s 981ms/step - accuracy: 0.9135 - loss: 0.2192 - val_accuracy: 0.8951 - val_loss: 0.2673 - learning_rate: 0.0010
# Epoch 12/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 807ms/step - accuracy: 0.9098 - loss: 0.2124
# Epoch 12: val_accuracy did not improve from 0.89508
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 37s 954ms/step - accuracy: 0.9098 - loss: 0.2123 - val_accuracy: 0.8787 - val_loss: 0.2978 - learning_rate: 0.0010
# Epoch 13/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 801ms/step - accuracy: 0.9291 - loss: 0.1975
# Epoch 13: val_accuracy did not improve from 0.89508
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 39s 990ms/step - accuracy: 0.9291 - loss: 0.1976 - val_accuracy: 0.8885 - val_loss: 0.2948 - learning_rate: 0.0010
# Epoch 14/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 843ms/step - accuracy: 0.9359 - loss: 0.1665
# Epoch 14: val_accuracy did not improve from 0.89508
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 39s 995ms/step - accuracy: 0.9357 - loss: 0.1670 - val_accuracy: 0.8885 - val_loss: 0.2684 - learning_rate: 0.0010
# Epoch 15/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 835ms/step - accuracy: 0.9060 - loss: 0.2464
# Epoch 15: val_accuracy did not improve from 0.89508
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9060 - loss: 0.2460 - val_accuracy: 0.8951 - val_loss: 0.2459 - learning_rate: 0.0010
# Epoch 16/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 852ms/step - accuracy: 0.9235 - loss: 0.2139
# Epoch 16: val_accuracy did not improve from 0.89508
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9235 - loss: 0.2137 - val_accuracy: 0.8951 - val_loss: 0.2465 - learning_rate: 0.0010
# Epoch 17/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 852ms/step - accuracy: 0.9054 - loss: 0.1996
# Epoch 17: val_accuracy improved from 0.89508 to 0.90164, saving model to best_minecraft_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9056 - loss: 0.1997 - val_accuracy: 0.9016 - val_loss: 0.2539 - learning_rate: 0.0010
# Epoch 18/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 834ms/step - accuracy: 0.9568 - loss: 0.1417
# Epoch 18: val_accuracy did not improve from 0.90164
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 39s 988ms/step - accuracy: 0.9565 - loss: 0.1420 - val_accuracy: 0.8951 - val_loss: 0.3478 - learning_rate: 0.0010
# Epoch 19/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 799ms/step - accuracy: 0.9376 - loss: 0.1784
# Epoch 19: val_accuracy did not improve from 0.90164
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 37s 948ms/step - accuracy: 0.9376 - loss: 0.1784 - val_accuracy: 0.8852 - val_loss: 0.2608 - learning_rate: 0.0010
# Epoch 20/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 798ms/step - accuracy: 0.9380 - loss: 0.1634
# Epoch 20: val_accuracy did not improve from 0.90164
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 37s 943ms/step - accuracy: 0.9380 - loss: 0.1637 - val_accuracy: 0.8951 - val_loss: 0.2978 - learning_rate: 0.0010
# Epoch 21/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 808ms/step - accuracy: 0.9320 - loss: 0.1767
# Epoch 21: val_accuracy did not improve from 0.90164
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 37s 953ms/step - accuracy: 0.9320 - loss: 0.1766 - val_accuracy: 0.8885 - val_loss: 0.2625 - learning_rate: 5.0000e-04
# Epoch 22/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 805ms/step - accuracy: 0.9472 - loss: 0.1579
# Epoch 22: val_accuracy did not improve from 0.90164
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 38s 982ms/step - accuracy: 0.9472 - loss: 0.1579 - val_accuracy: 0.8918 - val_loss: 0.2927 - learning_rate: 5.0000e-04
# Epoch 23/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 838ms/step - accuracy: 0.9331 - loss: 0.1628
# Epoch 23: val_accuracy did not improve from 0.90164
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9333 - loss: 0.1627 - val_accuracy: 0.8918 - val_loss: 0.3130 - learning_rate: 5.0000e-04
# Epoch 24/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 848ms/step - accuracy: 0.9318 - loss: 0.1649
# Epoch 24: val_accuracy did not improve from 0.90164
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9317 - loss: 0.1651 - val_accuracy: 0.8918 - val_loss: 0.2894 - learning_rate: 5.0000e-04
# Epoch 25/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 827ms/step - accuracy: 0.9170 - loss: 0.1842
# Epoch 25: val_accuracy did not improve from 0.90164
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 38s 979ms/step - accuracy: 0.9174 - loss: 0.1837 - val_accuracy: 0.9016 - val_loss: 0.2708 - learning_rate: 5.0000e-04
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 15.
# ✅ Entrenamiento completado!
# 📊 Evaluando modelo...
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 736ms/step
#
# 📋 Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#     aldeanos       0.93      0.83      0.88        93
#     creepers       0.95      0.93      0.94       114
#        vacas       0.82      0.92      0.87        98
#
#     accuracy                           0.90       305
#    macro avg       0.90      0.89      0.89       305
# weighted avg       0.90      0.90      0.90       305
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 💾 Modelo guardado como: minecraft_mob_classifier_final.h5
#
# 🎉 ¡Entrenamiento completado!
# 💡 Para usar el modelo:
#    trainer.predict_single_image('path_to_image.jpg')

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from PIL import Image
import os

class MinecraftPredictor:
    def __init__(self, model_path, class_names=None):
        """
        Inicializa el predictor de mobs
        model_path: ruta al modelo .h5 entrenado
        class_names: lista de nombres de clases (si no se proporciona, usa orden alfabético)
        """
        self.model = keras.models.load_model(model_path)
        self.img_size = 224  # Tamaño usado en entrenamiento
        
        # Nombres de clases (ajusta según tu orden)
        if class_names is None:
            self.class_names = ['aldeanos', 'creepers', 'vacas']  # Orden alfabético típico
        else:
            self.class_names = class_names
            
        print(f"✅ Modelo cargado: {model_path}")
        print(f"🎯 Clases: {self.class_names}")
        
    def preprocess_image(self, image_path):
        """Preprocesa una imagen para predicción"""
        # Carga la imagen
        img = Image.open(image_path).convert('RGB')
        
        # Redimensiona a 224x224 (mismo tamaño del entrenamiento)
        img = img.resize((self.img_size, self.img_size), Image.LANCZOS)
        
        # Convierte a array y normaliza (0-1)
        img_array = np.array(img) / 255.0
        
        # Añade dimensión de batch
        img_array = np.expand_dims(img_array, axis=0)
        
        return img_array, img
        
    def predict_single(self, image_path):
        """Predice la clase de una sola imagen"""
        try:
            # Preprocesa la imagen
            img_array, original_img = self.preprocess_image(image_path)
            
            # Hace la predicción
            predictions = self.model.predict(img_array, verbose=0)
            
            # Obtiene la clase predicha y confianza
            predicted_class_idx = np.argmax(predictions[0])
            confidence = predictions[0][predicted_class_idx]
            predicted_class = self.class_names[predicted_class_idx]
            
            # Muestra resultados
            print(f"\n📸 Imagen: {os.path.basename(image_path)}")
            print(f"🎯 Predicción: {predicted_class}")
            print(f"🎲 Confianza: {confidence:.2%}")
            
            # Muestra todas las probabilidades
            print("\n📊 Todas las probabilidades:")
            for i, class_name in enumerate(self.class_names):
                prob = predictions[0][i]
                print(f"  {class_name}: {prob:.2%}")
                
            return predicted_class, confidence, original_img
            
        except Exception as e:
            print(f"❌ Error procesando {image_path}: {str(e)}")
            return None, None, None
            
    def predict_and_show(self, image_path):
        """Predice y muestra la imagen con resultado"""
        predicted_class, confidence, img = self.predict_single(image_path)
        
        if img is not None:
            plt.figure(figsize=(8, 6))
            plt.imshow(img)
            plt.title(f'Predicción: {predicted_class} ({confidence:.1%} confianza)', 
                     fontsize=14, fontweight='bold')
            plt.axis('off')
            plt.tight_layout()
            plt.show()
            
    def batch_predict(self, images_folder):
        """Predice múltiples imágenes de una carpeta"""
        supported_formats = {'.jpg', '.jpeg', '.png', '.bmp', '.tiff'}
        
        image_files = []
        for ext in supported_formats:
            image_files.extend([f for f in os.listdir(images_folder) 
                              if f.lower().endswith(ext)])
        
        if not image_files:
            print("❌ No se encontraron imágenes en la carpeta")
            return
            
        print(f"🔍 Encontradas {len(image_files)} imágenes")
        print("-" * 50)
        
        results = []
        for img_file in image_files:
            img_path = os.path.join(images_folder, img_file)
            predicted_class, confidence, _ = self.predict_single(img_path)
            if predicted_class:
                results.append({
                    'archivo': img_file,
                    'prediccion': predicted_class,
                    'confianza': confidence
                })
        
        # Resumen
        print(f"\n📋 Resumen de {len(results)} predicciones:")
        for result in results:
            print(f"  {result['archivo']}: {result['prediccion']} ({result['confianza']:.1%})")
            
        return results


def main():
    # Configuración
    MODEL_PATH = "minecraft_mob_classifier_final.h5"  # Tu modelo entrenado
    CLASS_NAMES = ['aldeanos', 'creepers', 'vacas']    # Ajusta según tu orden
    
    print("🎮 Predictor de Mobs de Minecraft")
    print("=" * 40)
    
    # Inicializa el predictor
    try:
        predictor = MinecraftPredictor(MODEL_PATH, CLASS_NAMES)
    except Exception as e:
        print(f"❌ Error cargando modelo: {e}")
        return
    
    # Ejemplos de uso:
    
    # 1. Predice una imagen específica
    predictor.predict_and_show("C:/Users/Janus/OneDrive - IUE/SEMESTRE 2025-2/IA II/Dataset/2025-09-22_00.17.45.png")
    
    # 2. Predice solo y muestra resultados en texto
    predictor.predict_single("C:/Users/Janus/OneDrive - IUE/SEMESTRE 2025-2/IA II/Dataset/2025-09-22_00.17.45.png")
    
    # 3. Predice todas las imágenes de una carpeta
    # predictor.batch_predict("imagenes_prueba/")
    
    print("\n💡 Para usar:")
    print("  predictor.predict_and_show('tu_imagen.png')")
    print("  predictor.batch_predict('carpeta_imagenes/')")


if __name__ == "__main__":
    main()
# Out:
# 🎮 Predictor de Mobs de Minecraft
# ========================================
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ✅ Modelo cargado: minecraft_mob_classifier_final.h5
# 🎯 Clases: ['aldeanos', 'creepers', 'vacas']
#
# 📸 Imagen: 2025-09-22_00.17.45.png
# 🎯 Predicción: creepers
# 🎲 Confianza: 81.97%
#
# 📊 Todas las probabilidades:
#   aldeanos: 17.85%
#   creepers: 81.97%
#   vacas: 0.18%
# 📸 Imagen: 2025-09-22_00.17.45.png
# 🎯 Predicción: creepers
# 🎲 Confianza: 81.97%
#
# 📊 Todas las probabilidades:
#   aldeanos: 17.85%
#   creepers: 81.97%
#   vacas: 0.18%
#
# 💡 Para usar:
#   predictor.predict_and_show('tu_imagen.png')
#   predictor.batch_predict('carpeta_imagenes/')
