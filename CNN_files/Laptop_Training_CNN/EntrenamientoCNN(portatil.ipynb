# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

class MinecraftCNNTrainer:
    def __init__(self, dataset_path, img_size=224, batch_size=32):
        self.dataset_path = dataset_path
        self.img_size = img_size
        self.batch_size = batch_size
        self.model = None
        self.history = None
        self.class_names = []
        
    def setup_data_generators(self):
        """Configura los generadores de datos con data augmentation"""
        print("🔧 Configurando generadores de datos...")
        
        # Data augmentation para entrenamiento
        train_datagen = ImageDataGenerator(
            rescale=1./255,
            rotation_range=20,
            width_shift_range=0.2,
            height_shift_range=0.2,
            shear_range=0.15,
            zoom_range=0.2,
            horizontal_flip=True,
            fill_mode='nearest',
            validation_split=0.2  # 80% train, 20% validation
        )
        
        # Solo rescaling para validación
        val_datagen = ImageDataGenerator(
            rescale=1./255,
            validation_split=0.2
        )
        
        # Generador de entrenamiento
        self.train_generator = train_datagen.flow_from_directory(
            self.dataset_path,
            target_size=(self.img_size, self.img_size),
            batch_size=self.batch_size,
            class_mode='categorical',
            subset='training',
            shuffle=True
        )
        
        # Generador de validación
        self.val_generator = val_datagen.flow_from_directory(
            self.dataset_path,
            target_size=(self.img_size, self.img_size),
            batch_size=self.batch_size,
            class_mode='categorical',
            subset='validation',
            shuffle=False
        )
        
        self.class_names = list(self.train_generator.class_indices.keys())
        self.num_classes = len(self.class_names)
        
        print(f"✅ Clases encontradas: {self.class_names}")
        print(f"📊 Imágenes de entrenamiento: {self.train_generator.samples}")
        print(f"📊 Imágenes de validación: {self.val_generator.samples}")
        
    def create_model(self, use_transfer_learning=True):
        """Crea el modelo CNN"""
        print("🧠 Creando modelo CNN...")
        
        if use_transfer_learning:
            # Modelo con Transfer Learning (MobileNetV2)
            base_model = MobileNetV2(
                weights='imagenet',
                include_top=False,
                input_shape=(self.img_size, self.img_size, 3)
            )
            base_model.trainable = False  # Congela las capas base inicialmente
            
            self.model = keras.Sequential([
                base_model,
                layers.GlobalAveragePooling2D(),
                layers.Dropout(0.3),
                layers.Dense(128, activation='relu'),
                layers.Dropout(0.2),
                layers.Dense(self.num_classes, activation='softmax')
            ])
            
            print("✅ Modelo con Transfer Learning creado (MobileNetV2)")
            
        else:
            # Modelo CNN desde cero
            self.model = keras.Sequential([
                layers.Conv2D(32, 3, activation='relu', input_shape=(self.img_size, self.img_size, 3)),
                layers.MaxPooling2D(),
                layers.Conv2D(64, 3, activation='relu'),
                layers.MaxPooling2D(),
                layers.Conv2D(128, 3, activation='relu'),
                layers.MaxPooling2D(),
                layers.Conv2D(128, 3, activation='relu'),
                layers.MaxPooling2D(),
                
                layers.Flatten(),
                layers.Dropout(0.5),
                layers.Dense(512, activation='relu'),
                layers.Dropout(0.3),
                layers.Dense(self.num_classes, activation='softmax')
            ])
            
            print("✅ Modelo CNN desde cero creado")
        
        # Compila el modelo
        self.model.compile(
            optimizer=Adam(learning_rate=0.001),
            loss='categorical_crossentropy',
            metrics=['accuracy']
        )
        
        print(f"📋 Resumen del modelo:")
        self.model.summary()
        
    def setup_callbacks(self):
        """Configura callbacks para el entrenamiento"""
        callbacks = [
            EarlyStopping(
                monitor='val_loss',
                patience=10,
                restore_best_weights=True,
                verbose=1
            ),
            ModelCheckpoint(
                'best_minecraft_model(portatil_cnn).h5',
                monitor='val_accuracy',
                save_best_only=True,
                verbose=1
            ),
            ReduceLROnPlateau(
                monitor='val_loss',
                factor=0.5,
                patience=5,
                min_lr=1e-7,
                verbose=1
            )
        ]
        return callbacks
        
    def train_model(self, epochs=50):
        """Entrena el modelo"""
        print(f"🚀 Iniciando entrenamiento por {epochs} épocas...")
        
        callbacks = self.setup_callbacks()
        
        self.history = self.model.fit(
            self.train_generator,
            validation_data=self.val_generator,
            epochs=epochs,
            callbacks=callbacks,
            verbose=1
        )
        
        print("✅ Entrenamiento completado!")
        
    def plot_training_history(self):
        """Visualiza el progreso del entrenamiento"""
        if self.history is None:
            print("❌ No hay historial de entrenamiento para mostrar")
            return
            
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
        
        # Accuracy
        ax1.plot(self.history.history['accuracy'], label='Training Accuracy')
        ax1.plot(self.history.history['val_accuracy'], label='Validation Accuracy')
        ax1.set_title('Model Accuracy')
        ax1.set_xlabel('Epoch')
        ax1.set_ylabel('Accuracy')
        ax1.legend()
        ax1.grid(True)
        
        # Loss
        ax2.plot(self.history.history['loss'], label='Training Loss')
        ax2.plot(self.history.history['val_loss'], label='Validation Loss')
        ax2.set_title('Model Loss')
        ax2.set_xlabel('Epoch')
        ax2.set_ylabel('Loss')
        ax2.legend()
        ax2.grid(True)
        
        plt.tight_layout()
        plt.show()
        
    def evaluate_model(self):
        """Evalúa el modelo en el conjunto de validación"""
        print("📊 Evaluando modelo...")
        
        # Predicciones en validación
        predictions = self.model.predict(self.val_generator)
        y_pred = np.argmax(predictions, axis=1)
        y_true = self.val_generator.classes
        
        # Classification report
        print("\n📋 Reporte de Clasificación:")
        print(classification_report(y_true, y_pred, target_names=self.class_names))
        
        # Matriz de confusión
        cm = confusion_matrix(y_true, y_pred)
        plt.figure(figsize=(8, 6))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                   xticklabels=self.class_names, yticklabels=self.class_names)
        plt.title('Matriz de Confusión - Mobs de Minecraft')
        plt.xlabel('Predicción')
        plt.ylabel('Verdadero')
        plt.show()
        
    def save_model(self, filename='minecraft_mob_classifier.h5'):
        """Guarda el modelo entrenado"""
        self.model.save(filename)
        print(f"💾 Modelo guardado como: {filename}")
        
    def load_model(self, filename):
        """Carga un modelo previamente entrenado"""
        self.model = keras.models.load_model(filename)
        print(f"📂 Modelo cargado desde: {filename}")
        
    def predict_single_image(self, image_path):
        """Predice la clase de una sola imagen"""
        if self.model is None:
            print("❌ Primero debes entrenar o cargar un modelo")
            return
            
        # Carga y preprocesa la imagen
        img = keras.preprocessing.image.load_img(image_path, target_size=(self.img_size, self.img_size))
        img_array = keras.preprocessing.image.img_to_array(img)
        img_array = np.expand_dims(img_array, axis=0) / 255.0
        
        # Hace la predicción
        predictions = self.model.predict(img_array)
        predicted_class = np.argmax(predictions[0])
        confidence = predictions[0][predicted_class]
        
        print(f"🎯 Predicción: {self.class_names[predicted_class]}")
        print(f"🎲 Confianza: {confidence:.2%}")
        
        return self.class_names[predicted_class], confidence


def main():
    # Configuración
    DATASET_PATH = "C:/Users/Usuario/OneDrive - IUE/SEMESTRE 2025-2/IA II/Dataset/Imagenes redimensionadas"  # Cambia por tu ruta
    IMG_SIZE = 224
    BATCH_SIZE = 32
    EPOCHS = 30
    
    print("🎮 Entrenador de CNN para Mobs de Minecraft")
    print("=" * 50)
    
    # Inicializa el entrenador
    trainer = MinecraftCNNTrainer(DATASET_PATH, IMG_SIZE, BATCH_SIZE)
    
    # Configura datos
    trainer.setup_data_generators()
    
    # Crea modelo (usa Transfer Learning por defecto)
    trainer.create_model(use_transfer_learning=False)  # Cambia a True para usar Transfer Learning
    
    # Entrena el modelo
    trainer.train_model(epochs=EPOCHS)
    
    # Visualiza resultados
    trainer.plot_training_history()
    trainer.evaluate_model()
    
    # Guarda el modelo
    trainer.save_model("minecraft_mob_classifier_final(portatil_cnn).h5")
    
    print("\n🎉 ¡Entrenamiento completado!")
    print("💡 Para usar el modelo:")
    print("   trainer.predict_single_image('path_to_image.jpg')")


if __name__ == "__main__":
    main()
# Out:
# 🎮 Entrenador de CNN para Mobs de Minecraft
# ==================================================
# 🔧 Configurando generadores de datos...
# Found 1228 images belonging to 3 classes.
# Found 305 images belonging to 3 classes.
# ✅ Clases encontradas: ['aldeanos', 'creepers', 'vacas']
# 📊 Imágenes de entrenamiento: 1228
# 📊 Imágenes de validación: 305
# 🧠 Creando modelo CNN...
# ✅ Modelo CNN desde cero creado
# 📋 Resumen del modelo:
# c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 24, 24, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 18432)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 18432)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 512)            │     9,437,696 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 3)              │         1,539 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,680,067 (36.93 MB)
#  Trainable params: 9,680,067 (36.93 MB)
#  Non-trainable params: 0 (0.00 B)
# 🚀 Iniciando entrenamiento por 30 épocas...
# c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 706ms/step - accuracy: 0.3641 - loss: 1.1970
# Epoch 1: val_accuracy improved from None to 0.37705, saving model to best_minecraft_model(portatil_cnn).h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 32s 758ms/step - accuracy: 0.4487 - loss: 1.0658 - val_accuracy: 0.3770 - val_loss: 1.2889 - learning_rate: 0.0010
# Epoch 2/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 718ms/step - accuracy: 0.5494 - loss: 0.9557
# Epoch 2: val_accuracy improved from 0.37705 to 0.40328, saving model to best_minecraft_model(portatil_cnn).h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 30s 763ms/step - accuracy: 0.5651 - loss: 0.9333 - val_accuracy: 0.4033 - val_loss: 1.1446 - learning_rate: 0.0010
# Epoch 3/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 706ms/step - accuracy: 0.5892 - loss: 0.8985
# Epoch 3: val_accuracy improved from 0.40328 to 0.59344, saving model to best_minecraft_model(portatil_cnn).h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 29s 746ms/step - accuracy: 0.6572 - loss: 0.8248 - val_accuracy: 0.5934 - val_loss: 1.0401 - learning_rate: 0.0010
# Epoch 4/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 712ms/step - accuracy: 0.7437 - loss: 0.6859
# Epoch 4: val_accuracy improved from 0.59344 to 0.67869, saving model to best_minecraft_model(portatil_cnn).h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 30s 751ms/step - accuracy: 0.7492 - loss: 0.6538 - val_accuracy: 0.6787 - val_loss: 0.7206 - learning_rate: 0.0010
# Epoch 5/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 706ms/step - accuracy: 0.7791 - loss: 0.5698
# Epoch 5: val_accuracy did not improve from 0.67869
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 29s 740ms/step - accuracy: 0.7883 - loss: 0.5458 - val_accuracy: 0.6590 - val_loss: 0.7422 - learning_rate: 0.0010
# Epoch 6/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 722ms/step - accuracy: 0.7972 - loss: 0.5027
# Epoch 6: val_accuracy improved from 0.67869 to 0.69508, saving model to best_minecraft_model(portatil_cnn).h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 30s 762ms/step - accuracy: 0.8013 - loss: 0.4863 - val_accuracy: 0.6951 - val_loss: 0.6895 - learning_rate: 0.0010
# Epoch 7/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 765ms/step - accuracy: 0.8304 - loss: 0.4270
# Epoch 7: val_accuracy improved from 0.69508 to 0.76066, saving model to best_minecraft_model(portatil_cnn).h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 32s 807ms/step - accuracy: 0.8379 - loss: 0.4240 - val_accuracy: 0.7607 - val_loss: 0.5523 - learning_rate: 0.0010
# Epoch 8/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 749ms/step - accuracy: 0.8286 - loss: 0.4198
# Epoch 8: val_accuracy improved from 0.76066 to 0.77705, saving model to best_minecraft_model(portatil_cnn).h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 31s 792ms/step - accuracy: 0.8445 - loss: 0.4070 - val_accuracy: 0.7770 - val_loss: 0.4928 - learning_rate: 0.0010
# Epoch 9/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 742ms/step - accuracy: 0.8445 - loss: 0.4246
# Epoch 9: val_accuracy did not improve from 0.77705
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 31s 779ms/step - accuracy: 0.8347 - loss: 0.4356 - val_accuracy: 0.7770 - val_loss: 0.4710 - learning_rate: 0.0010
# Epoch 10/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 736ms/step - accuracy: 0.8586 - loss: 0.3633
# Epoch 10: val_accuracy improved from 0.77705 to 0.81639, saving model to best_minecraft_model(portatil_cnn).h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 31s 777ms/step - accuracy: 0.8648 - loss: 0.3611 - val_accuracy: 0.8164 - val_loss: 0.4001 - learning_rate: 0.0010
# Epoch 11/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 743ms/step - accuracy: 0.8994 - loss: 0.2746
# Epoch 11: val_accuracy did not improve from 0.81639
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 31s 777ms/step - accuracy: 0.8925 - loss: 0.2895 - val_accuracy: 0.7934 - val_loss: 0.4451 - learning_rate: 0.0010
# Epoch 12/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 758ms/step - accuracy: 0.9167 - loss: 0.2597
# Epoch 12: val_accuracy improved from 0.81639 to 0.85902, saving model to best_minecraft_model(portatil_cnn).h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 31s 798ms/step - accuracy: 0.9104 - loss: 0.2593 - val_accuracy: 0.8590 - val_loss: 0.3474 - learning_rate: 0.0010
# Epoch 13/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 705ms/step - accuracy: 0.9039 - loss: 0.2497
# Epoch 13: val_accuracy did not improve from 0.85902
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 29s 739ms/step - accuracy: 0.9202 - loss: 0.2282 - val_accuracy: 0.8525 - val_loss: 0.3434 - learning_rate: 0.0010
# Epoch 14/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 710ms/step - accuracy: 0.9070 - loss: 0.2538
# Epoch 14: val_accuracy improved from 0.85902 to 0.88525, saving model to best_minecraft_model(portatil_cnn).h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 30s 751ms/step - accuracy: 0.9153 - loss: 0.2392 - val_accuracy: 0.8852 - val_loss: 0.3639 - learning_rate: 0.0010
# Epoch 15/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.9089 - loss: 0.2493
# Epoch 15: val_accuracy did not improve from 0.88525
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 29s 741ms/step - accuracy: 0.9145 - loss: 0.2451 - val_accuracy: 0.8098 - val_loss: 0.4029 - learning_rate: 0.0010
# Epoch 16/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9427 - loss: 0.1620
# Epoch 16: val_accuracy improved from 0.88525 to 0.89836, saving model to best_minecraft_model(portatil_cnn).h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 29s 748ms/step - accuracy: 0.9406 - loss: 0.1767 - val_accuracy: 0.8984 - val_loss: 0.2291 - learning_rate: 0.0010
# Epoch 17/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 714ms/step - accuracy: 0.9386 - loss: 0.1787
# Epoch 17: val_accuracy did not improve from 0.89836
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 29s 748ms/step - accuracy: 0.9487 - loss: 0.1632 - val_accuracy: 0.8590 - val_loss: 0.3526 - learning_rate: 0.0010
# Epoch 18/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9432 - loss: 0.1621
# Epoch 18: val_accuracy did not improve from 0.89836
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 29s 739ms/step - accuracy: 0.9389 - loss: 0.1657 - val_accuracy: 0.8295 - val_loss: 0.4152 - learning_rate: 0.0010
# Epoch 19/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 705ms/step - accuracy: 0.9404 - loss: 0.1829
# Epoch 19: val_accuracy improved from 0.89836 to 0.91475, saving model to best_minecraft_model(portatil_cnn).h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 29s 746ms/step - accuracy: 0.9503 - loss: 0.1575 - val_accuracy: 0.9148 - val_loss: 0.2573 - learning_rate: 0.0010
# Epoch 20/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 713ms/step - accuracy: 0.9578 - loss: 0.1096
# Epoch 20: val_accuracy did not improve from 0.91475
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 29s 748ms/step - accuracy: 0.9511 - loss: 0.1304 - val_accuracy: 0.8951 - val_loss: 0.2616 - learning_rate: 0.0010
# Epoch 21/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.9598 - loss: 0.1147
# Epoch 21: val_accuracy did not improve from 0.91475
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 29s 742ms/step - accuracy: 0.9520 - loss: 0.1340 - val_accuracy: 0.9148 - val_loss: 0.1956 - learning_rate: 0.0010
# Epoch 22/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 710ms/step - accuracy: 0.9537 - loss: 0.1409
# Epoch 22: val_accuracy did not improve from 0.91475
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 29s 744ms/step - accuracy: 0.9617 - loss: 0.1097 - val_accuracy: 0.9082 - val_loss: 0.3167 - learning_rate: 0.0010
# Epoch 23/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 716ms/step - accuracy: 0.9668 - loss: 0.0975
# Epoch 23: val_accuracy did not improve from 0.91475
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 30s 750ms/step - accuracy: 0.9593 - loss: 0.1314 - val_accuracy: 0.9016 - val_loss: 0.2172 - learning_rate: 0.0010
# Epoch 24/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 700ms/step - accuracy: 0.9554 - loss: 0.1314
# Epoch 24: val_accuracy did not improve from 0.91475
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 29s 734ms/step - accuracy: 0.9625 - loss: 0.1218 - val_accuracy: 0.8918 - val_loss: 0.3026 - learning_rate: 0.0010
# Epoch 25/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9683 - loss: 0.1070
# Epoch 25: val_accuracy improved from 0.91475 to 0.91803, saving model to best_minecraft_model(portatil_cnn).h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 29s 737ms/step - accuracy: 0.9617 - loss: 0.1127 - val_accuracy: 0.9180 - val_loss: 0.1936 - learning_rate: 0.0010
# Epoch 26/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 719ms/step - accuracy: 0.9655 - loss: 0.0863
# Epoch 26: val_accuracy did not improve from 0.91803
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 30s 754ms/step - accuracy: 0.9658 - loss: 0.0875 - val_accuracy: 0.8557 - val_loss: 0.5216 - learning_rate: 0.0010
# Epoch 27/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 701ms/step - accuracy: 0.9635 - loss: 0.1036
# Epoch 27: val_accuracy improved from 0.91803 to 0.93115, saving model to best_minecraft_model(portatil_cnn).h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 29s 740ms/step - accuracy: 0.9585 - loss: 0.1107 - val_accuracy: 0.9311 - val_loss: 0.2120 - learning_rate: 0.0010
# Epoch 28/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 710ms/step - accuracy: 0.9716 - loss: 0.0832
# Epoch 28: val_accuracy did not improve from 0.93115
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 29s 744ms/step - accuracy: 0.9691 - loss: 0.0911 - val_accuracy: 0.9311 - val_loss: 0.2227 - learning_rate: 0.0010
# Epoch 29/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 753ms/step - accuracy: 0.9810 - loss: 0.0728
# Epoch 29: val_accuracy improved from 0.93115 to 0.94754, saving model to best_minecraft_model(portatil_cnn).h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 31s 796ms/step - accuracy: 0.9805 - loss: 0.0743 - val_accuracy: 0.9475 - val_loss: 0.2020 - learning_rate: 0.0010
# Epoch 30/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 723ms/step - accuracy: 0.9702 - loss: 0.0950
# Epoch 30: val_accuracy did not improve from 0.94754
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 30s 758ms/step - accuracy: 0.9707 - loss: 0.0942 - val_accuracy: 0.9148 - val_loss: 0.2719 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 25.
# ✅ Entrenamiento completado!
# 📊 Evaluando modelo...
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 143ms/step
#
# 📋 Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#     aldeanos       0.95      0.78      0.86        93
#     creepers       0.90      1.00      0.95       114
#        vacas       0.91      0.95      0.93        98
#
#     accuracy                           0.92       305
#    macro avg       0.92      0.91      0.91       305
# weighted avg       0.92      0.92      0.92       305
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 💾 Modelo guardado como: minecraft_mob_classifier_final(portatil_cnn).h5
#
# 🎉 ¡Entrenamiento completado!
# 💡 Para usar el modelo:
#    trainer.predict_single_image('path_to_image.jpg')
